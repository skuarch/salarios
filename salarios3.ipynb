# %%
import pandas as pd
import numpy as np

# %%
df3 = pd.read_csv('thirdPart.csv')

# %%
df3 = df3.astype({"year": int})
df3 = df3.astype({"total_people_by_state_and_level": int})
df3 = df3.astype({"total_man_by_state_and_level": int})
df3 = df3.astype({"total_woman_by_state_and_level": int})
df3 = df3.astype({"total_people_by_state_and_year": int})
df3 = df3.astype({"total_man_by_state_and_year": int})
df3 = df3.astype({"total_woman_by_state_and_year": int})
df3 = df3.astype({"man_percentage_by_state_and_level": float})
df3 = df3.astype({"woman_percentage_by_state_and_level": float})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-bd739fa0e969> in <module>
#       3 df3 = df3.astype({"total_man_by_state_and_level": int})
#       4 df3 = df3.astype({"total_woman_by_state_and_level": int})
# ----> 5 df3 = df3.astype({"total_people_by_state_and_year": int})
#       6 df3 = df3.astype({"total_man_by_state_and_year": int})
#       7 df3 = df3.astype({"total_woman_by_state_and_year": int})
#
# ~/Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5855                 if col_name not in self:
#    5856                     raise KeyError(
# -> 5857                         "Only a column name can be used for the "
#    5858                         "key in a dtype mappings argument."
#    5859                     )
#
# KeyError: 'Only a column name can be used for the key in a dtype mappings argument.'

# %%
df3
# Out:
#       year           state                   level  \
# 0     2005  Aguascalientes        1 salario m¡nimo
# 1     2005  Aguascalientes         Menos de 1 s.m.
# 2     2005  Aguascalientes   M s de 1 hasta 2 s.m.
# 3     2005  Aguascalientes          M s de 10 s.m.
# 4     2005  Aguascalientes   M s de 2 hasta 3 s.m.
# ...    ...             ...                     ...
# 4450  2019       Zacatecas   M s de 2 hasta 3 s.m.
# 4451  2019       Zacatecas   M s de 3 hasta 5 s.m.
# 4452  2019       Zacatecas  M s de 5 hasta 10 s.m.
# 4453  2019       Zacatecas         No especificado
# 4454  2019       Zacatecas      No recibe ingresos
#
#       total_people_by_state_and_level  total_man_by_state_and_level  \
# 0                                3157                          3157
# 1                              118401                        111212
# 2                                5092                          3921
# 3                              257632                        124638
# 4                              140654                        135145
# ...                               ...                           ...
# 4450                           125065                        123622
# 4451                           160188                         93125
# 4452                            31272                         26261
# 4453                             5493                          3914
# 4454                            17483                         16920
#
#       total_woman_by_state_and_level  total_people_by_state_and_year  \
# 0                                  0                         1001646
# 1                               7189                         1001646
# 2                               1171                         1001646
# 3                             132994                         1001646
# 4                               5509                         1001646
# ...                              ...                             ...
# 4450                            1443                          854562
# 4451                           67063                          854562
# 4452                            5011                          854562
# 4453                            1579                          854562
# 4454                             563                          854562
#
#       total_man_by_state_and_year  total_woman_by_state_and_year  \
# 0                          718194                         283452
# 1                          718194                         283452
# 2                          718194                         283452
# 3                          718194                         283452
# 4                          718194                         283452
# ...                           ...                            ...
# 4450                       616004                         238558
# 4451                       616004                         238558
# 4452                       616004                         238558
# 4453                       616004                         238558
# 4454                       616004                         238558
#
#       man_percentage_by_state_and_level  woman_percentage_by_state_and_level  \
# 0                               100.000                                0.000
# 1                                93.928                                6.072
# 2                                77.003                               22.997
# 3                                48.378                               51.622
# 4                                96.083                                3.917
# ...                                 ...                                  ...
# 4450                             98.846                                1.154
# 4451                             58.135                               41.865
# 4452                             83.976                               16.024
# 4453                             71.254                               28.746
# 4454                             96.780                                3.220
#
#       rate_level
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 4450           0
# 4451           0
# 4452           0
# 4453           0
# 4454           0
#
# [4455 rows x 12 columns]

# %%
df['percentage_by_level_and_total_people_by_state_and_year'] = round((df['total_people_by_state_and_level'] / df['total_people_by_state_and_year']) * 100,3)

# %%
df
# Out:
#       year           state                   level  \
# 0     2005  Aguascalientes        1 salario m¡nimo
# 1     2005  Aguascalientes         Menos de 1 s.m.
# 2     2005  Aguascalientes   M s de 1 hasta 2 s.m.
# 3     2005  Aguascalientes          M s de 10 s.m.
# 4     2005  Aguascalientes   M s de 2 hasta 3 s.m.
# ...    ...             ...                     ...
# 4450  2019       Zacatecas   M s de 2 hasta 3 s.m.
# 4451  2019       Zacatecas   M s de 3 hasta 5 s.m.
# 4452  2019       Zacatecas  M s de 5 hasta 10 s.m.
# 4453  2019       Zacatecas         No especificado
# 4454  2019       Zacatecas      No recibe ingresos
#
#       total_people_by_state_and_level  total_man_by_state_and_level  \
# 0                                3157                          3157
# 1                              118401                        111212
# 2                                5092                          3921
# 3                              257632                        124638
# 4                              140654                        135145
# ...                               ...                           ...
# 4450                           125065                        123622
# 4451                           160188                         93125
# 4452                            31272                         26261
# 4453                             5493                          3914
# 4454                            17483                         16920
#
#       total_woman_by_state_and_level  total_people_by_state_and_year  \
# 0                                  0                         1001646
# 1                               7189                         1001646
# 2                               1171                         1001646
# 3                             132994                         1001646
# 4                               5509                         1001646
# ...                              ...                             ...
# 4450                            1443                          854562
# 4451                           67063                          854562
# 4452                            5011                          854562
# 4453                            1579                          854562
# 4454                             563                          854562
#
#       total_man_by_state_and_year  total_woman_by_state_and_year  \
# 0                          718194                         283452
# 1                          718194                         283452
# 2                          718194                         283452
# 3                          718194                         283452
# 4                          718194                         283452
# ...                           ...                            ...
# 4450                       616004                         238558
# 4451                       616004                         238558
# 4452                       616004                         238558
# 4453                       616004                         238558
# 4454                       616004                         238558
#
#       man_percentage_by_state_and_level  woman_percentage_by_state_and_level  \
# 0                               100.000                                0.000
# 1                                93.928                                6.072
# 2                                77.003                               22.997
# 3                                48.378                               51.622
# 4                                96.083                                3.917
# ...                                 ...                                  ...
# 4450                             98.846                                1.154
# 4451                             58.135                               41.865
# 4452                             83.976                               16.024
# 4453                             71.254                               28.746
# 4454                             96.780                                3.220
#
#       rate_level  percentage_by_level_and_total_people_by_state_and_year
# 0              0                                              0.315
# 1              0                                             11.821
# 2              0                                              0.508
# 3              0                                             25.721
# 4              0                                             14.042
# ...          ...                                                ...
# 4450           0                                             14.635
# 4451           0                                             18.745
# 4452           0                                              3.659
# 4453           0                                              0.643
# 4454           0                                              2.046
#
# [4455 rows x 13 columns]

# %%
minimum_salary = df[df['level'].str.match('1 salario m¡nimo')]

# %%
minimum_salary
# Out:
#       year                state             level  \
# 0     2005       Aguascalientes  1 salario m¡nimo
# 9     2005      Baja California  1 salario m¡nimo
# 18    2005  Baja California Sur  1 salario m¡nimo
# 27    2005             Campeche  1 salario m¡nimo
# 36    2005              Chiapas  1 salario m¡nimo
# ...    ...                  ...               ...
# 4410  2019           Tamaulipas  1 salario m¡nimo
# 4419  2019             Tlaxcala  1 salario m¡nimo
# 4428  2019             Veracruz  1 salario m¡nimo
# 4437  2019              Yucat n  1 salario m¡nimo
# 4446  2019            Zacatecas  1 salario m¡nimo
#
#       total_people_by_state_and_level  total_man_by_state_and_level  \
# 0                                3157                          3157
# 9                                3007                          2808
# 18                               4601                          4175
# 27                              27881                         20021
# 36                               9054                          7105
# ...                               ...                           ...
# 4410                            11133                          9750
# 4419                              599                           599
# 4428                            39827                         29780
# 4437                             3294                          3130
# 4446                            26610                         25059
#
#       total_woman_by_state_and_level  total_people_by_state_and_year  \
# 0                                  0                         1001646
# 9                                199                         2864432
# 18                               426                          510701
# 27                              7860                          821042
# 36                              1949                         4807543
# ...                              ...                             ...
# 4410                            1383                         2041272
# 4419                               0                          810461
# 4428                           10047                         4375634
# 4437                             164                         1263136
# 4446                            1551                          854562
#
#       total_man_by_state_and_year  total_woman_by_state_and_year  \
# 0                          718194                         283452
# 9                         1952086                         912346
# 18                         371519                         139182
# 27                         593926                         227116
# 36                        3763270                        1044273
# ...                           ...                            ...
# 4410                      1404099                         637173
# 4419                       536150                         274311
# 4428                      3312070                        1063564
# 4437                       859070                         404066
# 4446                       616004                         238558
#
#       man_percentage_by_state_and_level  woman_percentage_by_state_and_level  \
# 0                               100.000                                0.000
# 9                                93.382                                6.618
# 18                               90.741                                9.259
# 27                               71.809                               28.191
# 36                               78.474                               21.526
# ...                                 ...                                  ...
# 4410                             87.577                               12.423
# 4419                            100.000                                0.000
# 4428                             74.773                               25.227
# 4437                             95.021                                4.979
# 4446                             94.171                                5.829
#
#       rate_level  percentage_by_level_and_total_people_by_state_and_year
# 0              0                                              0.315
# 9              0                                              0.105
# 18             0                                              0.901
# 27             0                                              3.396
# 36             0                                              0.188
# ...          ...                                                ...
# 4410           0                                              0.545
# 4419           0                                              0.074
# 4428           0                                              0.910
# 4437           0                                              0.261
# 4446           0                                              3.114
#
# [495 rows x 13 columns]

# %%
minimum_salary[minimum_salary['state'].str.match('Ciudad de Mxico')]
#minimum_salary[minimum_salary['state'].str.match('Campeche')]
# Out:
#       year             state             level  \
# 54    2005  Ciudad de Mxico  1 salario m¡nimo
# 351   2006  Ciudad de Mxico  1 salario m¡nimo
# 648   2007  Ciudad de Mxico  1 salario m¡nimo
# 945   2008  Ciudad de Mxico  1 salario m¡nimo
# 1242  2009  Ciudad de Mxico  1 salario m¡nimo
# 1539  2010  Ciudad de Mxico  1 salario m¡nimo
# 1836  2011  Ciudad de Mxico  1 salario m¡nimo
# 2133  2012  Ciudad de Mxico  1 salario m¡nimo
# 2430  2013  Ciudad de Mxico  1 salario m¡nimo
# 2727  2014  Ciudad de Mxico  1 salario m¡nimo
# 3024  2015  Ciudad de Mxico  1 salario m¡nimo
# 3321  2016  Ciudad de Mxico  1 salario m¡nimo
# 3618  2017  Ciudad de Mxico  1 salario m¡nimo
# 3915  2018  Ciudad de Mxico  1 salario m¡nimo
# 4212  2019  Ciudad de Mxico  1 salario m¡nimo
#
#       total_people_by_state_and_level  total_man_by_state_and_level  \
# 54                              23154                         17451
# 351                              7712                          5427
# 648                              5751                          3694
# 945                              6587                          6587
# 1242                             9993                          7246
# 1539                             2321                          2321
# 1836                            13137                         11559
# 2133                            11389                         10617
# 2430                             4180                          3327
# 2727                             5751                          5751
# 3024                             2339                          2339
# 3321                             3806                          2171
# 3618                             3421                          1641
# 3915                             4214                          3442
# 4212                             1990                          1369
#
#       total_woman_by_state_and_level  total_people_by_state_and_year  \
# 54                              5703                         7786083
# 351                             2285                         7904733
# 648                             2057                         7884260
# 945                                0                         7869340
# 1242                            2747                         7400137
# 1539                               0                         7469616
# 1836                            1578                         7341021
# 2133                             772                         7611930
# 2430                             853                         7624863
# 2727                               0                         7362300
# 3024                               0                         7438213
# 3321                            1635                         7537005
# 3618                            1780                         7580267
# 3915                             772                         7713836
# 4212                             621                         3948001
#
#       total_man_by_state_and_year  total_woman_by_state_and_year  \
# 54                        5242139                        2543944
# 351                       5280348                        2624385
# 648                       5158919                        2725341
# 945                       5168123                        2701217
# 1242                      4877861                        2522276
# 1539                      4917822                        2551794
# 1836                      4771075                        2569946
# 2133                      4905553                        2706377
# 2430                      4906198                        2718665
# 2727                      4838264                        2524036
# 3024                      4943068                        2495145
# 3321                      5010296                        2526709
# 3618                      4926721                        2653546
# 3915                      5010630                        2703206
# 4212                      2598349                        1349652
#
#       man_percentage_by_state_and_level  woman_percentage_by_state_and_level  \
# 54                               75.369                               24.631
# 351                              70.371                               29.629
# 648                              64.232                               35.768
# 945                             100.000                                0.000
# 1242                             72.511                               27.489
# 1539                            100.000                                0.000
# 1836                             87.988                               12.012
# 2133                             93.222                                6.778
# 2430                             79.593                               20.407
# 2727                            100.000                                0.000
# 3024                            100.000                                0.000
# 3321                             57.042                               42.958
# 3618                             47.968                               52.032
# 3915                             81.680                               18.320
# 4212                             68.794                               31.206
#
#       rate_level  percentage_by_level_and_total_people_by_state_and_year
# 54             0                                              0.297
# 351            0                                              0.098
# 648            0                                              0.073
# 945            0                                              0.084
# 1242           0                                              0.135
# 1539           0                                              0.031
# 1836           0                                              0.179
# 2133           0                                              0.150
# 2430           0                                              0.055
# 2727           0                                              0.078
# 3024           0                                              0.031
# 3321           0                                              0.050
# 3618           0                                              0.045
# 3915           0                                              0.055
# 4212           0                                              0.050
